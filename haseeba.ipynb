# %%
# Importing libraries for data analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("results (1).csv")
df

# index_col='Roll Number'
# Out:
#       Roll Number                            Name Computer Networks Lab  \
# 0    160920733001           MOHAMMED MUZAMMIL ALI                     S
# 1    160920733002                 MOHD MOIZ UDDIN                     S
# 2    160920733003        ATEEQ BIN MUBARAK WAHLAN                     A
# 3    160920733004                  WASIF ALI KHAN                     S
# 4    160920733005            SYED HUMAYUN RASHEED                     S
# ..            ...                             ...                   ...
# 422  160320733305                  MOHAMMED ANNAS                     A
# 423  160320733306                 MOHAMMED SOHAIL                     B
# 424  160320733307        MOHAMMED LIYAQAT MOAZZAM                     A
# 425  160320733308         SYED SHAH MAAZ HUSSAINI                     A
# 426  160320733309  ABDULLAH HABEEB HASHIM BAFAQUI                     B
#
#     Artificial Intelligence Lab Principals of Programming Language  \
# 0                             A                                  C
# 1                             S                                  C
# 2                             S                                  B
# 3                             S                                  B
# 4                             S                                  B
# ..                          ...                                ...
# 422                           A                                  D
# 423                           A                                  D
# 424                           S                                  F
# 425                           A                                  F
# 426                           A                                  F
#
#     Artificial Intelligence Automata Language Computation  \
# 0                         D                             C
# 1                         A                             C
# 2                         B                             C
# 3                         B                             B
# 4                         S                             D
# ..                      ...                           ...
# 422                       F                             F
# 423                       F                             F
# 424                       F                             F
# 425                       F                             F
# 426                       F                             F
#
#     Software Engineering Computer Networks Software Engineering Lab  \
# 0                      C                 B                        A
# 1                      C                 A                        A
# 2                      B                 A                        A
# 3                      A                 A                        S
# 4                      C                 A                        S
# ..                   ...               ...                      ...
# 422                    E                 D                        C
# 423                    F                 F                        B
# 424                    F                 D                        C
# 425                    F                 F                        C
# 426                    F                 F                        C
#
#     Object Oriented Analysis Design  Current Sem Credits  Backlogs  \
# 0                                 D                   21         1
# 1                                 C                   21         0
# 2                                 B                   21         0
# 3                                 B                   21         0
# 4                                 C                   21         0
# ..                              ...                  ...       ...
# 422                             NaN                   15         6
# 423                             NaN                    6        15
# 424                             NaN                    6        11
# 425                             NaN                    6        13
# 426                             NaN                    3        11
#
#      Previous Pending  Overall GPA DATA SCIENCE BLOCK CHAIN TECHNOLOGIES  \
# 0                   3  PASSED-7.19          NaN                      NaN
# 1                   0  PASSED-7.95          NaN                      NaN
# 2                   0  PASSED-8.19          NaN                      NaN
# 3                   0  PASSED-8.57          NaN                      NaN
# 4                   0  PASSED-8.14          NaN                      NaN
# ..                ...          ...          ...                      ...
# 422                12   PROMOTED--          NaN                        B
# 423                30   PROMOTED--          NaN                        F
# 424                18   PROMOTED--          NaN                        F
# 425                24   PROMOTED--          NaN                        C
# 426                15   PROMOTED--          NaN                        F
#
#      Total Credits
# 0              101
# 1              104
# 2              104
# 3              104
# 4              104
# ..             ...
# 422             86
# 423             59
# 424             71
# 425             65
# 426             71
#
# [427 rows x 18 columns]

# %%
# Creating an array of all the students roll numbers including lateral enteries
normal_students_lords = np.arange(160920733001, 160920733180)
lateral_entry_lords = np.arange(160920733301, 160920733320)

normal_students_mj = np.arange(160420733001, 160420733122)
lateral_entry_mj = np.arange(160420733301, 160420733313)

normal_students_deccan = np.arange(160320733001, 160320733091)
lateral_entry_deccan = np.arange(160320733301, 160320733310)

# %%
# Combine roll numbers for each group into separate arrays
total_students_lords = np.concatenate((normal_students_lords, lateral_entry_lords))
total_students_mj = np.concatenate((normal_students_mj, lateral_entry_mj))
total_students_deccan = np.concatenate((normal_students_deccan, lateral_entry_deccan))

# Combine roll numbers of all groups into a single array
total_students = np.concatenate((total_students_deccan, total_students_mj, total_students_lords))

# %%
# Define discontinued roll numbers
discontinued_students = np.array([160920733156, 160920733176, 160320733078])

# Remove discontinued roll numbers
total_students = np.setdiff1d(total_students, discontinued_students)

# %%
# Creating a dictionary that maps the subject code to subject
subject_dic = {
    "502N" : "Computer Networks Lab",
    "502O" : "Artificial Intelligence Lab",
    "574" : "Software Engineering Lab",
    "585": "Artificial Intelligence",
    "503I": "Object Oriented Analysis Design",
    "518" : "Automata Language Computation",
    "535" : "Software Engineering",
    "538" : "Computer Networks",
    "503F" : "Principals of Programming Language",
    "503J" : "DATA SCIENCE",
    "596" : "BLOCK CHAIN TECHNOLOGIES"
}

# %%
# Creating an empty dataframe whose columns are the subject names of the semester

results_df = pd.DataFrame(index=total_students)
results_df.index.name = "Roll Number"
results_df
# Out:
# Empty DataFrame
# Columns: []
# Index: [160320733001, 160320733002, 160320733003, 160320733004, 160320733005, 160320733006, 160320733007, 160320733008, 160320733009, 160320733010, 160320733011, 160320733012, 160320733013, 160320733014, 160320733015, 160320733016, 160320733017, 160320733018, 160320733019, 160320733020, 160320733021, 160320733022, 160320733023, 160320733024, 160320733025, 160320733026, 160320733027, 160320733028, 160320733029, 160320733030, 160320733031, 160320733032, 160320733033, 160320733034, 160320733035, 160320733036, 160320733037, 160320733038, 160320733039, 160320733040, 160320733041, 160320733042, 160320733043, 160320733044, 160320733045, 160320733046, 160320733047, 160320733048, 160320733049, 160320733050, 160320733051, 160320733052, 160320733053, 160320733054, 160320733055, 160320733056, 160320733057, 160320733058, 160320733059, 160320733060, 160320733061, 160320733062, 160320733063, 160320733064, 160320733065, 160320733066, 160320733067, 160320733068, 160320733069, 160320733070, 160320733071, 160320733072, 160320733073, 160320733074, 160320733075, 160320733076, 160320733077, 160320733079, 160320733080, 160320733081, 160320733082, 160320733083, 160320733084, 160320733085, 160320733086, 160320733087, 160320733088, 160320733089, 160320733090, 160320733301, 160320733302, 160320733303, 160320733304, 160320733305, 160320733306, 160320733307, 160320733308, 160320733309, 160420733001, 160420733002, ...]
#
# [427 rows x 0 columns]

# %%
df.head(5)
# Out:
#     Roll Number                      Name Computer Networks Lab  \
# 0  160920733001     MOHAMMED MUZAMMIL ALI                     S
# 1  160920733002           MOHD MOIZ UDDIN                     S
# 2  160920733003  ATEEQ BIN MUBARAK WAHLAN                     A
# 3  160920733004            WASIF ALI KHAN                     S
# 4  160920733005      SYED HUMAYUN RASHEED                     S
#
#   Artificial Intelligence Lab Principals of Programming Language  \
# 0                           A                                  C
# 1                           S                                  C
# 2                           S                                  B
# 3                           S                                  B
# 4                           S                                  B
#
#   Artificial Intelligence Automata Language Computation Software Engineering  \
# 0                       D                             C                    C
# 1                       A                             C                    C
# 2                       B                             C                    B
# 3                       B                             B                    A
# 4                       S                             D                    C
#
#   Computer Networks Software Engineering Lab Object Oriented Analysis Design  \
# 0                 B                        A                               D
# 1                 A                        A                               C
# 2                 A                        A                               B
# 3                 A                        S                               B
# 4                 A                        S                               C
#
#    Current Sem Credits  Backlogs  Previous Pending  Overall GPA DATA SCIENCE  \
# 0                   21         1                 3  PASSED-7.19          NaN
# 1                   21         0                 0  PASSED-7.95          NaN
# 2                   21         0                 0  PASSED-8.19          NaN
# 3                   21         0                 0  PASSED-8.57          NaN
# 4                   21         0                 0  PASSED-8.14          NaN
#
#   BLOCK CHAIN TECHNOLOGIES  Total Credits
# 0                      NaN            101
# 1                      NaN            104
# 2                      NaN            104
# 3                      NaN            104
# 4                      NaN            104

# %%
df.tail(5)
df
# Out:
#       Roll Number                            Name Computer Networks Lab  \
# 0    160920733001           MOHAMMED MUZAMMIL ALI                     S
# 1    160920733002                 MOHD MOIZ UDDIN                     S
# 2    160920733003        ATEEQ BIN MUBARAK WAHLAN                     A
# 3    160920733004                  WASIF ALI KHAN                     S
# 4    160920733005            SYED HUMAYUN RASHEED                     S
# ..            ...                             ...                   ...
# 422  160320733305                  MOHAMMED ANNAS                     A
# 423  160320733306                 MOHAMMED SOHAIL                     B
# 424  160320733307        MOHAMMED LIYAQAT MOAZZAM                     A
# 425  160320733308         SYED SHAH MAAZ HUSSAINI                     A
# 426  160320733309  ABDULLAH HABEEB HASHIM BAFAQUI                     B
#
#     Artificial Intelligence Lab Principals of Programming Language  \
# 0                             A                                  C
# 1                             S                                  C
# 2                             S                                  B
# 3                             S                                  B
# 4                             S                                  B
# ..                          ...                                ...
# 422                           A                                  D
# 423                           A                                  D
# 424                           S                                  F
# 425                           A                                  F
# 426                           A                                  F
#
#     Artificial Intelligence Automata Language Computation  \
# 0                         D                             C
# 1                         A                             C
# 2                         B                             C
# 3                         B                             B
# 4                         S                             D
# ..                      ...                           ...
# 422                       F                             F
# 423                       F                             F
# 424                       F                             F
# 425                       F                             F
# 426                       F                             F
#
#     Software Engineering Computer Networks Software Engineering Lab  \
# 0                      C                 B                        A
# 1                      C                 A                        A
# 2                      B                 A                        A
# 3                      A                 A                        S
# 4                      C                 A                        S
# ..                   ...               ...                      ...
# 422                    E                 D                        C
# 423                    F                 F                        B
# 424                    F                 D                        C
# 425                    F                 F                        C
# 426                    F                 F                        C
#
#     Object Oriented Analysis Design  Current Sem Credits  Backlogs  \
# 0                                 D                   21         1
# 1                                 C                   21         0
# 2                                 B                   21         0
# 3                                 B                   21         0
# 4                                 C                   21         0
# ..                              ...                  ...       ...
# 422                             NaN                   15         6
# 423                             NaN                    6        15
# 424                             NaN                    6        11
# 425                             NaN                    6        13
# 426                             NaN                    3        11
#
#      Previous Pending  Overall GPA DATA SCIENCE BLOCK CHAIN TECHNOLOGIES  \
# 0                   3  PASSED-7.19          NaN                      NaN
# 1                   0  PASSED-7.95          NaN                      NaN
# 2                   0  PASSED-8.19          NaN                      NaN
# 3                   0  PASSED-8.57          NaN                      NaN
# 4                   0  PASSED-8.14          NaN                      NaN
# ..                ...          ...          ...                      ...
# 422                12   PROMOTED--          NaN                        B
# 423                30   PROMOTED--          NaN                        F
# 424                18   PROMOTED--          NaN                        F
# 425                24   PROMOTED--          NaN                        C
# 426                15   PROMOTED--          NaN                        F
#
#      Total Credits
# 0              101
# 1              104
# 2              104
# 3              104
# 4              104
# ..             ...
# 422             86
# 423             59
# 424             71
# 425             65
# 426             71
#
# [427 rows x 18 columns]

# %%
# # Remove the 'Current Sem Credits' and 'Previous Pending' columns
# df = df.drop(columns=['Current Sem Credits', 'Previous Pending'])
# df

# %%
# saving the results df in a csv file locally
df.to_csv('results.csv')
# reading from the same csv file, the roll number column is no longer the index
df = pd.read_csv('results.csv')
# retiving the first 10 rows
df.head(10)
df
# Out:
#      Unnamed: 0   Roll Number                            Name  \
# 0             0  160920733001           MOHAMMED MUZAMMIL ALI
# 1             1  160920733002                 MOHD MOIZ UDDIN
# 2             2  160920733003        ATEEQ BIN MUBARAK WAHLAN
# 3             3  160920733004                  WASIF ALI KHAN
# 4             4  160920733005            SYED HUMAYUN RASHEED
# ..          ...           ...                             ...
# 422         422  160320733305                  MOHAMMED ANNAS
# 423         423  160320733306                 MOHAMMED SOHAIL
# 424         424  160320733307        MOHAMMED LIYAQAT MOAZZAM
# 425         425  160320733308         SYED SHAH MAAZ HUSSAINI
# 426         426  160320733309  ABDULLAH HABEEB HASHIM BAFAQUI
#
#     Computer Networks Lab Artificial Intelligence Lab  \
# 0                       S                           A
# 1                       S                           S
# 2                       A                           S
# 3                       S                           S
# 4                       S                           S
# ..                    ...                         ...
# 422                     A                           A
# 423                     B                           A
# 424                     A                           S
# 425                     A                           A
# 426                     B                           A
#
#     Principals of Programming Language Artificial Intelligence  \
# 0                                    C                       D
# 1                                    C                       A
# 2                                    B                       B
# 3                                    B                       B
# 4                                    B                       S
# ..                                 ...                     ...
# 422                                  D                       F
# 423                                  D                       F
# 424                                  F                       F
# 425                                  F                       F
# 426                                  F                       F
#
#     Automata Language Computation Software Engineering Computer Networks  \
# 0                               C                    C                 B
# 1                               C                    C                 A
# 2                               C                    B                 A
# 3                               B                    A                 A
# 4                               D                    C                 A
# ..                            ...                  ...               ...
# 422                             F                    E                 D
# 423                             F                    F                 F
# 424                             F                    F                 D
# 425                             F                    F                 F
# 426                             F                    F                 F
#
#     Software Engineering Lab Object Oriented Analysis Design  \
# 0                          A                               D
# 1                          A                               C
# 2                          A                               B
# 3                          S                               B
# 4                          S                               C
# ..                       ...                             ...
# 422                        C                             NaN
# 423                        B                             NaN
# 424                        C                             NaN
# 425                        C                             NaN
# 426                        C                             NaN
#
#      Current Sem Credits  Backlogs  Previous Pending  Overall GPA  \
# 0                     21         1                 3  PASSED-7.19
# 1                     21         0                 0  PASSED-7.95
# 2                     21         0                 0  PASSED-8.19
# 3                     21         0                 0  PASSED-8.57
# 4                     21         0                 0  PASSED-8.14
# ..                   ...       ...               ...          ...
# 422                   15         6                12   PROMOTED--
# 423                    6        15                30   PROMOTED--
# 424                    6        11                18   PROMOTED--
# 425                    6        13                24   PROMOTED--
# 426                    3        11                15   PROMOTED--
#
#     DATA SCIENCE BLOCK CHAIN TECHNOLOGIES  Total Credits
# 0            NaN                      NaN            101
# 1            NaN                      NaN            104
# 2            NaN                      NaN            104
# 3            NaN                      NaN            104
# 4            NaN                      NaN            104
# ..           ...                      ...            ...
# 422          NaN                        B             86
# 423          NaN                        F             59
# 424          NaN                        F             71
# 425          NaN                        C             65
# 426          NaN                        F             71
#
# [427 rows x 19 columns]

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
# setting the index of the dataFrame to the Roll Number column
df = df.set_index("Roll Number")
df.index
# Out:
# Index([160920733001, 160920733002, 160920733003, 160920733004, 160920733005,
#        160920733006, 160920733007, 160920733008, 160920733009, 160920733010,
#        ...
#        160320733090, 160320733301, 160320733302, 160320733303, 160320733304,
#        160320733305, 160320733306, 160320733307, 160320733308, 160320733309],
#       dtype='int64', name='Roll Number', length=427)

# %%
df
# Out:
#                                         Name Computer Networks Lab  \
# Roll Number
# 160920733001           MOHAMMED MUZAMMIL ALI                     S
# 160920733002                 MOHD MOIZ UDDIN                     S
# 160920733003        ATEEQ BIN MUBARAK WAHLAN                     A
# 160920733004                  WASIF ALI KHAN                     S
# 160920733005            SYED HUMAYUN RASHEED                     S
# ...                                      ...                   ...
# 160320733305                  MOHAMMED ANNAS                     A
# 160320733306                 MOHAMMED SOHAIL                     B
# 160320733307        MOHAMMED LIYAQAT MOAZZAM                     A
# 160320733308         SYED SHAH MAAZ HUSSAINI                     A
# 160320733309  ABDULLAH HABEEB HASHIM BAFAQUI                     B
#
#              Artificial Intelligence Lab Principals of Programming Language  \
# Roll Number
# 160920733001                           A                                  C
# 160920733002                           S                                  C
# 160920733003                           S                                  B
# 160920733004                           S                                  B
# 160920733005                           S                                  B
# ...                                  ...                                ...
# 160320733305                           A                                  D
# 160320733306                           A                                  D
# 160320733307                           S                                  F
# 160320733308                           A                                  F
# 160320733309                           A                                  F
#
#              Artificial Intelligence Automata Language Computation  \
# Roll Number
# 160920733001                       D                             C
# 160920733002                       A                             C
# 160920733003                       B                             C
# 160920733004                       B                             B
# 160920733005                       S                             D
# ...                              ...                           ...
# 160320733305                       F                             F
# 160320733306                       F                             F
# 160320733307                       F                             F
# 160320733308                       F                             F
# 160320733309                       F                             F
#
#              Software Engineering Computer Networks Software Engineering Lab  \
# Roll Number
# 160920733001                    C                 B                        A
# 160920733002                    C                 A                        A
# 160920733003                    B                 A                        A
# 160920733004                    A                 A                        S
# 160920733005                    C                 A                        S
# ...                           ...               ...                      ...
# 160320733305                    E                 D                        C
# 160320733306                    F                 F                        B
# 160320733307                    F                 D                        C
# 160320733308                    F                 F                        C
# 160320733309                    F                 F                        C
#
#              Object Oriented Analysis Design  Current Sem Credits  Backlogs  \
# Roll Number
# 160920733001                               D                   21         1
# 160920733002                               C                   21         0
# 160920733003                               B                   21         0
# 160920733004                               B                   21         0
# 160920733005                               C                   21         0
# ...                                      ...                  ...       ...
# 160320733305                             NaN                   15         6
# 160320733306                             NaN                    6        15
# 160320733307                             NaN                    6        11
# 160320733308                             NaN                    6        13
# 160320733309                             NaN                    3        11
#
#               Previous Pending  Overall GPA DATA SCIENCE  \
# Roll Number
# 160920733001                 3  PASSED-7.19          NaN
# 160920733002                 0  PASSED-7.95          NaN
# 160920733003                 0  PASSED-8.19          NaN
# 160920733004                 0  PASSED-8.57          NaN
# 160920733005                 0  PASSED-8.14          NaN
# ...                        ...          ...          ...
# 160320733305                12   PROMOTED--          NaN
# 160320733306                30   PROMOTED--          NaN
# 160320733307                18   PROMOTED--          NaN
# 160320733308                24   PROMOTED--          NaN
# 160320733309                15   PROMOTED--          NaN
#
#              BLOCK CHAIN TECHNOLOGIES  Total Credits
# Roll Number
# 160920733001                      NaN            101
# 160920733002                      NaN            104
# 160920733003                      NaN            104
# 160920733004                      NaN            104
# 160920733005                      NaN            104
# ...                               ...            ...
# 160320733305                        B             86
# 160320733306                        F             59
# 160320733307                        F             71
# 160320733308                        C             65
# 160320733309                        F             71
#
# [427 rows x 17 columns]

# %%
# Assigning a section to students based on their roll number
# Lords
df.loc[:160920733060, "Section"] = "CSE A-Lords"
df.loc[160920733061:160920733120, "Section"] = "CSE B-Lords"
df.loc[160920733121:160920733179, "Section"] = "CSE C-Lords"
df.loc[160920733301:160920733306, "Section"] = "CSE A-Lords"
df.loc[160920733307:160920733312, "Section"] = "CSE B-Lords"
df.loc[160920733313:160920733319, "Section"] = "CSE C-Lords"
# Mj
df.loc[:160420733060, "Section"] = "CSE AA-MJ"
df.loc[160420733061:160420733121, "Section"] = "CSE BB-MJ"
df.loc[160420733301:160420733306, "Section"] = "CSE AA-MJ"
df.loc[160420733307:160420733312, "Section"] = "CSE BB-MJ"
# deccan
df.loc[:160320733045, "Section"] = "CSE AAA-Deccan"
df.loc[160320733046:160320733090, "Section"] = "CSE BBB-Deccan"
df.loc[160320733301:160320733305, "Section"] = "CSE AAA-Deccan"
df.loc[160320733306:160320733309, "Section"] = "CSE BBB-Deccan"


df.sample()
# Out:
#                              Name Computer Networks Lab  \
# Roll Number
# 160420733121  MOHAMMAD AAZAM KHAN                     D
#
#              Artificial Intelligence Lab Principals of Programming Language  \
# Roll Number
# 160420733121                           C                                  F
#
#              Artificial Intelligence Automata Language Computation  \
# Roll Number
# 160420733121                       D                             F
#
#              Software Engineering Computer Networks Software Engineering Lab  \
# Roll Number
# 160420733121                    F                 F                        A
#
#              Object Oriented Analysis Design  Current Sem Credits  Backlogs  \
# Roll Number
# 160420733121                             NaN                    9         8
#
#               Previous Pending Overall GPA DATA SCIENCE  \
# Roll Number
# 160420733121                15  PROMOTED--          NaN
#
#              BLOCK CHAIN TECHNOLOGIES  Total Credits         Section
# Roll Number
# 160420733121                        D             77  CSE AAA-Deccan

# %%
# checking for null values
df.isna().sum()
# Out:
# Name                                    0
# Computer Networks Lab                   0
# Artificial Intelligence Lab             0
# Principals of Programming Language      0
# Artificial Intelligence                 0
# Automata Language Computation           0
# Software Engineering                    0
# Computer Networks                       0
# Software Engineering Lab                0
# Object Oriented Analysis Design       231
# Current Sem Credits                     0
# Backlogs                                0
# Previous Pending                        0
# Overall GPA                             0
# DATA SCIENCE                          351
# BLOCK CHAIN TECHNOLOGIES              272
# Total Credits                           0
# Section                                 0
# dtype: int64

# %%
df.shape
# Out:
# (427, 18)

# %%
# Removing null columns
df = df.dropna()

# %%
df.isna().sum()
# Out:
# Name                                  0
# Computer Networks Lab                 0
# Artificial Intelligence Lab           0
# Principals of Programming Language    0
# Artificial Intelligence               0
# Automata Language Computation         0
# Software Engineering                  0
# Computer Networks                     0
# Software Engineering Lab              0
# Object Oriented Analysis Design       0
# Current Sem Credits                   0
# Backlogs                              0
# Previous Pending                      0
# Overall GPA                           0
# DATA SCIENCE                          0
# BLOCK CHAIN TECHNOLOGIES              0
# Total Credits                         0
# Section                               0
# dtype: int64

# %%
# replacing 'Promoted' with '-1'
df = df.replace('PROMOTED--', "-1")

# Removing the substring 'PASSED-' from all the students that have cleared
df["Overall GPA"] = df["Overall GPA"].str.replace("PASSED-", "")

# %%
# Converting GPA to numeric values
df['Overall GPA'] = pd.to_numeric(df['Overall GPA'])
df['Overall GPA']
# Out:
# Series([], Name: Overall GPA, dtype: int64)

# %%
# Creating a DataFrame that consistes only of Name GPA and section
df = df.loc[:,["Name", "Overall GPA", "Section", "Total Credits", 
                                                "Backlogs"]
                                            ]
df.head(10)
# Out:
# Empty DataFrame
# Columns: [Name, Overall GPA, Section, Total Credits, Backlogs]
# Index: []
